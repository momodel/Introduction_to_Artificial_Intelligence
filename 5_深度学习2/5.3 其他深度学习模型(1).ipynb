# %% [markdown]
# <h1><span class="motutor-highlight motutor-id_b4wk4y0-id_492litz"><i></i>Autoencoder和VAE等</span></h1>

# %% [markdown]
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/autoencoder.png" width="700px"/></div>
# </div>

# %% [markdown]
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/VAE.jpeg" width="700px"/></div>
# </div>
