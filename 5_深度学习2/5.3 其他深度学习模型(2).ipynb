# %% [markdown]
# <h1><span class="motutor-highlight motutor-id_xcxnnot-id_moyltun"><i></i>模型组合</span></h1>

# %% [markdown]
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/dnn_ensemble.jpeg" width="700px"/></div>
# </div>

# %% [markdown]
# <h1><span class="motutor-highlight motutor-id_e094gx4-id_ezju7ys"><i></i>多任务学习</span></h1>

# %% [markdown]
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/multi_task.png" width="700px"/></div>
# </div>
