# %% [markdown]
# ## 为什么更深的网络很难训练

# %% [markdown]
# 梯度消失（梯度爆炸）问题：<b>当网络隐藏层较多时，前面的网络层<span class="motutor-highlight motutor-id_5q46hfj-id_9sq0yco"><i></i>很难学习到知识</span></b>
#
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/vanishing_gradient_2.png" width="600px"/></div>
# </div>

# %% [markdown]
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/vanishing_gradient.png" width="400px"/></div>
# </div>

# %% [markdown]
# 1. 2006年，Geoffrey Hinton 和他的学生 Ruslan Salakhutdinov 提出了深层网络训练中<span class="motutor-highlight motutor-id_jak8cx2-id_cluylkb"><i></i>梯度消失问题的解决方案</span>：无监督预训练对权值进行初始化+有监督训练微调。
#
# 2. 2011年，ReLU 激活函数被提出，该激活函数能够有效的抑制梯度消失问题。
#
# 3. 算力的提升和海量的训练数据

# %% [markdown]
# <h2><span class="motutor-highlight motutor-id_8z6a9yf-id_ao4bh5i"><i></i>深度网络的效果</span></h2>
#
# <div align=left>
# <video src="https://imgbed.momodel.cn/3 New Things An AI Can Do With Your Photos.mp4" controls="controls" width=700 title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen>
# </div>

# %% [markdown]
# <h2><span class="motutor-highlight motutor-id_mtoxph4-id_xcp0uzw"><i></i>从大数据到大模型</span></h2>

# %% [markdown]
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/big_data_model.png" width="800px"/></div>
# </div>

# %% [markdown]
# **进一步阅读**：
#
# Neural Networks and Deep Learning：http://neuralnetworksanddeeplearning.com/
