# %% [markdown]
# <h1>判断过拟合 - <span class="motutor-highlight motutor-id_9gxo9lc-id_2zruzs1"><i></i>学习曲线</span></h1>
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/learning_curve.png" width="700px"/></div>
# </div>

# %% [markdown]
# <h2> “避免”过拟合</h2>
#
# 1. <span class="motutor-highlight motutor-id_kasfv0y-id_svd2sk2"><i></i>模型选择、特征选择（如PCA）</span>
# 2. <span class="motutor-highlight motutor-id_kasfv0y-id_cktx8ak"><i></i>"大数据"</span>
# 3. <span class="motutor-highlight motutor-id_kasfv0y-id_cauts4q"><i></i>正则化: </span>
#     * $L^* = L + \frac{\lambda}{m}\sum_i \theta_i^2$
#     * $L^* = L + \frac{\lambda}{m}\sum_i |\theta_i|$
#     * ...
# 4. <span class="motutor-highlight motutor-id_kasfv0y-id_84fjeyu"><i></i>模型聚合及其变形（如Dropout）</span>
