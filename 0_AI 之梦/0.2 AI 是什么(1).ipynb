# %% [markdown]
# ## AI是什么？

# %% [markdown]
# ### **<span class="motutor-highlight motutor-id_3uvy3jv-id_q7b78wv"><i></i>人类的智能是什么？</span>**

# %% [markdown]
# > 在一系列环境下，<span class="motutor-highlight motutor-id_iusetjf-id_1cho9ai"><i></i>解决一系列任务的能力</span>

# %% [markdown]
# <span class="motutor-highlight motutor-id_dt8xuah-id_ky5nax2"><i></i>弱人工智能(Artificial Narrow Intelligence，ANI)</span>
#
# 强人工智能(Artificial General Intelligence，AGI)
#
# 超人工智能(Artificial Superintelligence，ASI)

# %% [markdown]
# ### <span class="motutor-highlight motutor-id_n517ip1-id_2zt4nz7"><i></i>人工智能 = 机器学习 ?</span>

# %% [markdown]
# ## <span class="motutor-highlight motutor-id_2gc9wd7-id_yqd4n9l"><i></i>y=f(x)</span>

# %% [markdown]
# 机器学习：<span class="motutor-highlight motutor-id_yshq203-id_yldhkab"><i></i>f的自动学习</span>
#
# 学习的方法：<span class="motutor-highlight motutor-id_yshq203-id_kn3ey6k"><i></i>观察数据</span>

# %% [markdown]
# ### <span class="motutor-highlight motutor-id_qx7gzki-id_hn3vh3p"><i></i>智能即学习，学习即迁移</span>

# %% [markdown]
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/AILearning.png" width="800px"/></div>
# </div>
