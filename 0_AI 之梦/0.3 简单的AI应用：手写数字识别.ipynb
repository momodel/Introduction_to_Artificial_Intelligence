# %% [markdown]
# # 简单的 AI 应用：<span class="motutor-highlight motutor-id_4xf0xho-id_579yuty"><i></i>手写数字识别</span>

# %% [markdown]
# <span class="motutor-highlight motutor-id_rsqo3u9-id_gfn5xoh"><i></i>接下来我们将用一个封装好的`python`程序来进行手写数字识别，实现一个简单的`AI`应用</span>

# %% [markdown]
# <span class="motutor-highlight motutor-id_b1j1es4-id_86aliht"><i></i>首先我们需要引入一些必要的`python`库以及我们封装好的程序</span>

# %%
# 引入必要的 python 库
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from mnist import mnist_plot
from mnist import plot_digits
from mnist import mnist_preidct

# %% [markdown]
# 接下来我们简单画一下`MNIST`数据集中的数字，`MNIST`手写数字数据集也被称为人工智能领域的 ABC ，主要由一些手写数字的图片和相应的标签组成，图片一共有10 类，分别对应从0～9 ，<span class="motutor-highlight motutor-id_5llfb0q-id_z7bongb"><i></i>共10 个阿拉伯数字</span>。

# %%
# 建立画布
plt.figure(figsize=(9,9))
# 绘制图像
plot_digits()

# %% [markdown]
# 我们可以看到从0到9十个阿拉伯数字的手写体，同样的，<span class="motutor-highlight motutor-id_3yg8txn-id_tgxww1a"><i></i>我们可以使用函数画出你想要的数字：</span>

# %%
# 你可以尝试改变数字来画出不同的手写数字
a = mnist_plot(8)

# %% [markdown]
# 最后我们调用函数去预测一下<span class="motutor-highlight motutor-id_cjtjolo-id_zt0rbl4"><i></i>你刚刚画出的数字是什么：</span>

# %%
mnist_preidct(a)

# %% [markdown]
# 结果可能是对的，也可能不太准。一方面是因为我们的模型比较简单，另一方面模型并非能做到完全没有错误（人也是这样的），通过接下来的学习，你能够学到更多关于模型调整的知识。
