# %% [markdown]
# ## 从确定性计算与不确定性学习

# %% [markdown]
# ### **确定性计算 和 <span class="motutor-highlight motutor-id_p3xu10z-id_mrbscm7"><i></i>早期人工智能</span>**
#
# 符号主义AI（Symbolic AI）：<span class="motutor-highlight motutor-id_p3xu10z-id_3uo6cz1"><i></i>基于符号表示+数理逻辑+搜索的人工智能</span>
#
# 1. 符号表示：将知识表达为符号
# 2. 数理逻辑：符号逻辑演绎（自19世纪末起得以迅速发展，20世纪30年代开始用于描述智能行为）
# 3. 搜索：在海量演绎空间中寻找最优
#
# > 启发式（Heuristic）算法 <span class="motutor-highlight motutor-id_p3xu10z-id_vgx2s3f"><i></i>逻辑理论家:证明38条数学定理（Allen Newell）</span>
#
# > 专家系统

# %% [markdown]
# **代表人物**
# <span class="motutor-highlight motutor-id_t1kfmgq-id_2bgasyb"><i></i>Herbert Simon</span>（1978年获得诺贝尔经济学奖，1975年获得图灵奖-与Allen Newell一起）、Nils Nilsson（A\*算法，AI教科书）、吴文俊。
#
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/simon.jpg" width="200px"/></div>
# </div>
#
# > 图片来源：https://understandingsociety.blogspot.com/2019/06/herbert-simons-theories-of-organizations.html

# %% [markdown]
# ### **不确定性 与 机器学习**
#
# 1. 手写体识别：<span class="motutor-highlight motutor-id_a9t2edn-id_s18ku1i"><i></i>28\*28图像 -> 0-9数字 </span>
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/MnistExamples.png" width="300px"/></div>
# </div>
#
# 2. <span class="motutor-highlight motutor-id_a9t2edn-id_64t87d0"><i></i>自动驾驶</span>
#
#    世界的随机性、不确定性和动态性 - <span class="motutor-highlight motutor-id_a9t2edn-id_qk1gihw"><i></i>**需要模式识别（学习）的能力，从数据中总结规律**</span>

# %% [markdown]
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/MLHistory.jpg" width="800px"/></div>
# </div>
#
# > 图片来源：https://zhuanlan.zhihu.com/p/43833351
