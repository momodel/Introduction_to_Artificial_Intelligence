# %% [markdown]
# ## <span class="motutor-highlight motutor-id_hh0jxbf-id_57qv8av"><i></i>机器学习基础概念</span>

# %% [markdown]
# 函数(模型）<span class="motutor-highlight motutor-id_yhfgcdk-id_os0j8ty"><i></i> $f$ （模型类型）</span>
#
# <span class="motutor-highlight motutor-id_yhfgcdk-id_kprq186"><i></i>参数 $\theta$ （参数 vs. 超参数）</span>
#
# 特征(输入） <span class="motutor-highlight motutor-id_yhfgcdk-id_7qi04wn"><i></i>$x$</span>
#
# 目标（输出） $y$ （预测目标 $y^* = f_\theta(x)$)
#
# 数据 $D=\{(x_i, y_i) | i=1,...,m\}$

# %% [markdown]
# ### 训练和推理
#
# 训练数据、测试数据、<span class="motutor-highlight motutor-id_zlfkzwr-id_gtando4"><i></i>推理数据</span>
#
# “**预测**”即推理

# %% [markdown]
# ### <span class="motutor-highlight motutor-id_fx33zop-id_it51xc1"><i></i>分类和回归</span>
#
# * $y$是数值 - 回归问题
# * $y$是类别（标签） - 分类问题

# %% [markdown]
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/medical_imaging.jpg" width="700px"/></div>
# </div>
#
# > Image source: https://qure.ai/

# %% [markdown]
# ### <span class="motutor-highlight motutor-id_jf560gs-id_hx6j7o8"><i></i>监督和无监督</span>
#
# * 监督： $D=\{(x_i, y_i)\}$
# * 无监督：$D=\{(x_i)\}$
# * 半监督
