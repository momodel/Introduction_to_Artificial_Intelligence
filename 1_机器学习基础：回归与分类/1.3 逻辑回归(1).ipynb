# %% [markdown]
# # 逻辑回归

# %% [markdown]
# <span class="motutor-highlight motutor-id_0nxfkbm-id_o587sna"><i></i>分类：把回归结果（$-\infty$, $\infty$）转化到0 / 1</span>

# %% [markdown]
# **<span class="motutor-highlight motutor-id_qlaz9ts-id_75se6is"><i></i>sigmoid 函数</span>: **
#
# $$ g(z)=\frac{1}{1+e^{-z}} $$

# %% [markdown]
# <div class='insertContainerBox column'>
# <div class='insertItem' align=left><img src="images/softmax.png" width="300px"/></div>
# </div>

# %% [markdown]
# **<span class="motutor-highlight motutor-id_58goc5p-id_4kveeia"><i></i>逻辑回归分布函数</span>**
#
# $$f(x)=g(ax+b) = \frac{1}{1+e^{-(ax+b)}} $$

# %% [markdown]
# **胸围、腰围 -> 判断男生、女生**
#
# $x_1$: 胸围
#
# $x_2$: 腰围
#
# $y$: 0代表女生，1代表男生
