# %% [markdown]
# ## <span class="motutor-highlight motutor-id_jlcstet-id_8i4o8wk"><i></i>房价预测问题</span>

# %% [markdown]
# x: 楼盘距离市中心的距离
#
# y：楼盘单价
#
# 如何用x来预测y？

# %% [markdown]
# 机器学习的流程：
# 1. 准备训练数据
# 2. 选择模型
# 3. 选择损失函数
# 4. **训练**：梯度下降优化损失函数，找到最优参数
# 5. **推理**：用训练好的模型，输入新的$x$，预测$y$
